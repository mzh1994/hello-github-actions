# %% [markdown]
# # Code for Scrapping Data from Wikipedia and Creating Table

# %% [markdown]
# Installing necessary libraries and importing table from HTML

# %%
import bs4 as bs
import urllib.request
import pandas as pd

source = urllib.request.urlopen('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').read()
soup = bs.BeautifulSoup(source,'html.parser')

table = soup.find('table', class_='wikitable sortable')
table_rows = table.find_all('tr')

# %%
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text for tr in td]
    l.append(row)
df = pd.DataFrame(l, columns=["Postal_Code", "Borough","Neighborhood"])

# %% [markdown]
# ## DataFrame created

# %%
df
# Out:
#     Postal_Code         Borough  \
# 0          None            None
# 1         M1A\n  Not assigned\n
# 2         M2A\n  Not assigned\n
# 3         M3A\n    North York\n
# 4         M4A\n    North York\n
# ..          ...             ...
# 176       M5Z\n  Not assigned\n
# 177       M6Z\n  Not assigned\n
# 178       M7Z\n  Not assigned\n
# 179       M8Z\n     Etobicoke\n
# 180       M9Z\n  Not assigned\n
#
#                                           Neighborhood
# 0                                                 None
# 1                                                   \n
# 2                                                   \n
# 3                                          Parkwoods\n
# 4                                   Victoria Village\n
# ..                                                 ...
# 176                                                 \n
# 177                                                 \n
# 178                                                 \n
# 179  Mimico NW, The Queensway West, South of Bloor,...
# 180                                                 \n
#
# [181 rows x 3 columns]

# %% [markdown]
# ### Removing Not Assigned from Borough

# %%
df_f = df[df['Borough']!='Not assigned\n']
a = df_f.Neighborhood=="Not assigned\n"
a.any() #checking for any not assigned value in Neighborhood; found None
df_f
# Out:
#     Postal_Code             Borough  \
# 0          None                None
# 3         M3A\n        North York\n
# 4         M4A\n        North York\n
# 5         M5A\n  Downtown Toronto\n
# 6         M6A\n        North York\n
# ..          ...                 ...
# 161       M8X\n         Etobicoke\n
# 166       M4Y\n  Downtown Toronto\n
# 169       M7Y\n      East Toronto\n
# 170       M8Y\n         Etobicoke\n
# 179       M8Z\n         Etobicoke\n
#
#                                           Neighborhood
# 0                                                 None
# 3                                          Parkwoods\n
# 4                                   Victoria Village\n
# 5                          Regent Park, Harbourfront\n
# 6                   Lawrence Manor, Lawrence Heights\n
# ..                                                 ...
# 161    The Kingsway, Montgomery Road, Old Mill North\n
# 166                             Church and Wellesley\n
# 169            Business reply mail Processing Centre\n
# 170  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 179  Mimico NW, The Queensway West, South of Bloor,...
#
# [104 rows x 3 columns]

# %%
df_f.drop([0], inplace = True) #dropping first None values
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df_f #Checking DataFrame
# Out:
#     Postal_Code             Borough  \
# 3         M3A\n        North York\n
# 4         M4A\n        North York\n
# 5         M5A\n  Downtown Toronto\n
# 6         M6A\n        North York\n
# 7         M7A\n  Downtown Toronto\n
# ..          ...                 ...
# 161       M8X\n         Etobicoke\n
# 166       M4Y\n  Downtown Toronto\n
# 169       M7Y\n      East Toronto\n
# 170       M8Y\n         Etobicoke\n
# 179       M8Z\n         Etobicoke\n
#
#                                           Neighborhood
# 3                                          Parkwoods\n
# 4                                   Victoria Village\n
# 5                          Regent Park, Harbourfront\n
# 6                   Lawrence Manor, Lawrence Heights\n
# 7        Queen's Park, Ontario Provincial Government\n
# ..                                                 ...
# 161    The Kingsway, Montgomery Road, Old Mill North\n
# 166                             Church and Wellesley\n
# 169            Business reply mail Processing Centre\n
# 170  Old Mill South, King's Mill Park, Sunnylea, Hu...
# 179  Mimico NW, The Queensway West, South of Bloor,...
#
# [103 rows x 3 columns]

# %% [markdown]
# ### Final DataFrame

# %%
d = df_f.groupby("Postal_Code")["Neighborhood"].apply(",".join).reset_index() #Joining all same neighbours

# %%
d #Final DataFrame
# Out:
#     Postal_Code                                       Neighborhood
# 0         M1B\n                                   Malvern, Rouge\n
# 1         M1C\n           Rouge Hill, Port Union, Highland Creek\n
# 2         M1E\n                Guildwood, Morningside, West Hill\n
# 3         M1G\n                                           Woburn\n
# 4         M1H\n                                        Cedarbrae\n
# ..          ...                                                ...
# 98        M9N\n                                           Weston\n
# 99        M9P\n                                        Westmount\n
# 100       M9R\n  Kingsview Village, St. Phillips, Martin Grove ...
# 101       M9V\n  South Steeles, Silverstone, Humbergate, Jamest...
# 102       M9W\n                                        Northwest\n
#
# [103 rows x 2 columns]

# %%
d["Borough"] = df_f["Borough"] #Adding Borough

# %%
d #Checking again
# Out:
#     Postal_Code                                       Neighborhood  \
# 0         M1B\n                                   Malvern, Rouge\n
# 1         M1C\n           Rouge Hill, Port Union, Highland Creek\n
# 2         M1E\n                Guildwood, Morningside, West Hill\n
# 3         M1G\n                                           Woburn\n
# 4         M1H\n                                        Cedarbrae\n
# ..          ...                                                ...
# 98        M9N\n                                           Weston\n
# 99        M9P\n                                        Westmount\n
# 100       M9R\n  Kingsview Village, St. Phillips, Martin Grove ...
# 101       M9V\n  South Steeles, Silverstone, Humbergate, Jamest...
# 102       M9W\n                                        Northwest\n
#
#            Borough
# 0              NaN
# 1              NaN
# 2              NaN
# 3     North York\n
# 4     North York\n
# ..             ...
# 98             NaN
# 99          York\n
# 100  Scarborough\n
# 101   North York\n
# 102            NaN
#
# [103 rows x 3 columns]

# %%
d.dropna(subset=["Borough"], inplace = True)

# %%
d = d[["Postal_Code","Neighborhood","Borough"]] #Rearranging DataFrame

# %%
d
# Out:
#     Postal_Code                                       Neighborhood  \
# 3         M1G\n                                           Woburn\n
# 4         M1H\n                                        Cedarbrae\n
# 5         M1J\n                              Scarborough Village\n
# 6         M1K\n      Kennedy Park, Ionview, East Birchmount Park\n
# 7         M1L\n                  Golden Mile, Clairlea, Oakridge\n
# ..          ...                                                ...
# 95        M9C\n  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 96        M9L\n                                    Humber Summit\n
# 99        M9P\n                                        Westmount\n
# 100       M9R\n  Kingsview Village, St. Phillips, Martin Grove ...
# 101       M9V\n  South Steeles, Silverstone, Humbergate, Jamest...
#
#                 Borough
# 3          North York\n
# 4          North York\n
# 5    Downtown Toronto\n
# 6          North York\n
# 7    Downtown Toronto\n
# ..                  ...
# 95    Central Toronto\n
# 96               York\n
# 99               York\n
# 100       Scarborough\n
# 101        North York\n
#
# [67 rows x 3 columns]

# %%
cols_to_check = ["Postal_Code", "Borough","Neighborhood"] #Remoning \n Caharcter
d[cols_to_check] = d[cols_to_check].replace({'\n':''}, regex=True)

# %% [markdown]
# ## Final Result

# %%
e = d.reset_index() #Final Result
e = e.drop("index",axis=1)
e
# Out:
#    Postal_Code                                       Neighborhood  \
# 0          M1G                                             Woburn
# 1          M1H                                          Cedarbrae
# 2          M1J                                Scarborough Village
# 3          M1K        Kennedy Park, Ionview, East Birchmount Park
# 4          M1L                    Golden Mile, Clairlea, Oakridge
# ..         ...                                                ...
# 62         M9C  Eringate, Bloordale Gardens, Old Burnhamthorpe...
# 63         M9L                                      Humber Summit
# 64         M9P                                          Westmount
# 65         M9R  Kingsview Village, St. Phillips, Martin Grove ...
# 66         M9V  South Steeles, Silverstone, Humbergate, Jamest...
#
#              Borough
# 0         North York
# 1         North York
# 2   Downtown Toronto
# 3         North York
# 4   Downtown Toronto
# ..               ...
# 62   Central Toronto
# 63              York
# 64              York
# 65       Scarborough
# 66        North York
#
# [67 rows x 3 columns]

# %%
print("Final shape of DataFrame is {}".format(e.shape))
# Out:
# Final shape of DataFrame is (67, 3)
